# %% [markdown]
# # Lab 4. My first data science project

# %% [markdown]
# ## In this lab you will apply the concepts and techniques developed in sessions 1-6. You are expected to work on the assignments on your own between Tuesday the 8th at 11am and Wednesday the 9th at 11 am. We recomend hadning in an hour early to aviod any issues with traffic on the ELE.
#
# ## You are expected to submit the code developed as well as a brief description of your findings and insights for each assigment.
#
# ## You can do this by creating [markdown cells](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm#:~:text=%20Jupyter%20Notebook%20-%20Markdown%20Cells%20%201,To%20attach%20link%20to%20text%2C%20place...%20More%20) in jupyter notebook, and writting in them.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
### Let's load the gapminder dataset
gapminder = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### (1) Use pairplot to visualise the data. Colour code data points by the continent they are from.

# %% [markdown]
# ## Code used for (1)
#
# fig = sns.pairplot(gapminder, hue='continent')

# %%
fig = sns.pairplot(gapminder, hue='continent')

# %% [markdown]
# ### (2) What patterns can you see? Are there any outliars?

# %% [markdown]
# ## We can see life Expectancy is highest in the Europe and lowest in continent of Africa. Africa has a normal distribution for life expectancy with mean value around 50 years
# ## It is also clear most of the continent have relatively slow growth in population compared to Asia having the highest growth rate of population across the given years. Asia almost has a perfectly linear relationship for population across years.
# ## gdpPercap of the Asia have few outliers between 1950-1975.
# ## America has consistent linear growth in gdpPercap

# %% [markdown]
# ### (3) Filter the dataset to find rows in which life GDP per capita is greater than 60,000

# %% [markdown]
# ### Code used for (3) :
#
# gdpPercap = gapminder['gdpPercap']>60000
#
# gapminder[gdpPercap]

# %%
gdpPercap = gapminder['gdpPercap']>60000

# %%
gapminder[gdpPercap]
# Out:
#     country continent  year  lifeExp     pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700

# %% [markdown]
# ### (4) What does this tell us about the data, as seen in the question (1)  pairplot?

# %% [markdown]
# ## Based on above data of answer (3), it is clear that 'Kuwait' is the outlier from the graph of gdpPerCap showing Outliers for Asia continent, contributing all the gdpPercap values above 60000 compared to all other continents

# %% [markdown]
# ### (5) Find the rows in the dataframe with the top 20 life expectancies

# %%
#I have used sort_values() function and iloc[] to get expected output


sorted_lifeExp = gapminder.sort_values(by = 'lifeExp' , ascending=False)

sorted_lifeExp.iloc[0:20]
# Out:
#                country continent  year  lifeExp        pop    gdpPercap
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 802              Japan      Asia  2002   82.000  127065841  28604.59190
# 695            Iceland    Europe  2007   81.757     301931  36180.78919
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.41907
# 670   Hong Kong, China      Asia  2002   81.495    6762476  30209.01516
# 71           Australia   Oceania  2007   81.235   20434176  34435.36744
# 1427             Spain    Europe  2007   80.941   40448191  28821.06370
# 1475            Sweden    Europe  2007   80.884    9031088  33859.74835
# 767             Israel      Asia  2007   80.745    6426679  25523.27710
# 801              Japan      Asia  1997   80.690  125956499  28816.58499
# 539             France    Europe  2007   80.657   61083916  30470.01670
# ...

# %% [markdown]
# ## Code used for 5:
#
# sorted_lifeExp = gapminder.sort_values(by = 'lifeExp' , ascending=False)
#
# sorted_lifeExp.iloc[0:20]

# %% [markdown]
# ### (6) Plot the evolution of life expectancy, population and GDP per capita of Kuwait

# %%
lifeExp_pop_gdp = gapminder['country'] == 'Kuwait'

# %%
#This is ploted without using subplots, showing comparions of evolution of life expectancy, population and GDP per capita of Kuwait

gapminder[lifeExp_pop_gdp][['lifeExp','pop','gdpPercap']].plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Code used for (6)
#
# lifeExp_pop_gdp = gapminder['country'] == 'Kuwait'
#
# gapminder[lifeExp_pop_gdp][['lifeExp','pop','gdpPercap']].plot(figsize=(10,10))
#
# gapminder[lifeExp_pop_gdp][['lifeExp','pop','gdpPercap']].plot(subplots=True, figsize=(10,10))

# %%
#This code is used to show individual evolution of all : life expectancy, population and GDP per capita of Kuwait
gapminder[lifeExp_pop_gdp][['lifeExp','pop','gdpPercap']].plot(subplots=True, figsize=(10,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# ### (7) Visualise the distribution of GDP per capita of countries and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# #### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# #### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
#Included hue parameter to show distribution acroess the continents since there are lot of countries to display a good visualisation
sns.jointplot(data=gapminder, x='lifeExp', y='gdpPercap')

# %%
#This graph shows linear regression of vairables: gdpPercap and lifeExp across countries from dataframe

sns.regplot(x='lifeExp', y='gdpPercap', data=gapminder)
# Out:
# <AxesSubplot:xlabel='lifeExp', ylabel='gdpPercap'>

# %% [markdown]
# ## Code used for (7):
#
# sns.jointplot(data=gapminder, x='lifeExp', y='gdpPercap', hue = 'continent')
#
# sns.regplot(x='lifeExp', y='gdpPercap', data=gapminder)

# %% [markdown]
# ### (8) Visualise the distribution of year and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
#Use of hue= continent is used to give more information of the required visualisation
sns.displot(gapminder, x='year', y='lifeExp',hue= 'continent')

# %%
sns.regplot(x='year', y='lifeExp', data=gapminder)
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %% [markdown]
# ## Code used for (8)
#
# sns.displot(gapminder, x='year', y='lifeExp',hue= 'continent')
#
# sns.regplot(x='year', y='lifeExp', data=gapminder)

# %% [markdown]
# ### (9) Use Boxplots or violinplots to visualise the distribution of change in life expectancy from 1952 to 2007.
#
# Hint tools from lab 6 may be helpful.

# %%
#Created a dataframe to life expectancy for only year 1952
df_1952 = gapminder[gapminder['year']==1952]

# %%
#Created a dataframe to life expectancy for only year 2007
df_2007 = gapminder[gapminder['year']==2007]

# %%
#Used contact() method from pandas to combine these dataframes
Change_lifeExp = pd.concat([df_1952, df_2007], axis=0)

# %%
Change_lifeExp
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12               Albania    Europe  1952   55.230   1282697  1601.056136
# 24               Algeria    Africa  1952   43.077   9279525  2449.008185
# 36                Angola    Africa  1952   30.015   4232095  3520.610273
# 48             Argentina  Americas  1952   62.485  17876956  5911.315053
# ...                  ...       ...   ...      ...       ...          ...
# 1655             Vietnam      Asia  2007   74.249  85262356  2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332  3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035  1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143   469.709298
#
# [284 rows x 6 columns]

# %%
#To show change in life Expectancy of two years, I have used the concatinated dafatframe and plotted its boxplot

ax = sns.boxplot(x='year', y='lifeExp', data=Change_lifeExp)
ax.set_title('Change in life expectancy from 1952 to 2007')
ax.set_xlabel('Year')
ax.set_ylabel('Life Expectancy')
# Out:
# Text(0, 0.5, 'Life Expectancy')

# %% [markdown]
# ## Code used for (9)
#
# df_1952 = gapminder[gapminder['year']==1952]
#
# df_2007 = gapminder[gapminder['year']==2007]
#
# Change_lifeExp = pd.concat([df_1952, df_2007], axis=0)
#
# ax = sns.boxplot(x='year', y='lifeExp', data=Change_lifeExp)
#
# ax.set_title('Change in life expectancy from 1952 to 2007')
#
# ax.set_xlabel('Year')
#
# ax.set_ylabel('Life Expectancy')

# %% [markdown]
# ### (10) Continue this analysis of the data. Include code cells, their outputs and markdown cells where you write about your findings. What patterns can you observe in the data?

# %%
#Code cell

df_1952 = gapminder[gapminder['year']==1952]

df_2007 = gapminder[gapminder['year']==2007]

Change_lifeExp = pd.concat([df_1952, df_2007], axis=0)

ax = sns.boxplot(x='year', y='lifeExp', data=Change_lifeExp)

ax.set_title('Change in life expectancy from 1952 to 2007')

ax.set_xlabel('Year')

ax.set_ylabel('Life Expectancy')
# Out:
# Text(0, 0.5, 'Life Expectancy')

# %% [markdown]
# ## From above boxplot, we can see that, there is a substantial increase in the life Expectancy in year 2007 compared to year 1952; where the maximum life expectancy was 60 years in 1952, in 2007 it is somewhere near 77-78 years. The median value of life expectancy for year 1952 is around 55 years, whereas for year 2007 it is increased to somewhere around 73 years.
#
# ## Majority of the population had life expectancy between 55 to 60 years as per the upper quartile of year 1952
#
# ## Majority of population had life expectancy between 58 to 73 years as per the lower quartile of year 2007
#
# ### There are no outliers for the data presented above
